# %%
###diccionaries###

# Definicion

my_dict = dict()
my_other_dict = {}
print(type(my_dict))
print(type(my_other_dict))


my_other_dict = {"Nombre":"fermin",
                 "Apellido":"garcia","edad":35,1:"python"}

my_dict =  {
         "Nombre":"Fermin",
         "Apellido":"Garcia",
        "Edad" : 35,
        "lenguajes" : ("Python","swift","kotlin"),
        1:1.77
}


print(my_other_dict)
print(my_dict)

print(len(my_other_dict))
print(len(my_dict))

# Busqueda

print(my_dict[1])
print(my_dict["Nombre"])


print("Garcia"in my_dict)
print("Apellido"in my_dict)

# insercion

my_dict["calle"] = "calle Garcia"
print(my_dict)

# Actualizacion

 my_dict("Nombre") = "juan",
 print(my_dict("Nombre"))

 # Eliminacion

 del my_dict["calle"]
print(my_dict)

# Otras operaciones

print(my_dict.item())
print(my_dict.keus())
print(my_dict.voules())

my_list = ["Nombre",1,"piso"]

my_new_dict = dict.fromkeys((my_list))
print(my_new_dict)
my_new_dict = dict.fromkeys(("Nombre":1"piso"))
print((my_new_dict))
my_new_dict =dict.fromkeys(my_dict)
print((my_new_dict))
my_new_dict = dict.fromkeys(my_dict,"Garcia")
print((my_new_dict))

my_values = my_dict_voules()
print()type (my_values)

print(my_new_dict.values())
print(list(dict.fromkeys(list(my_new_dict.values())).leys()))
print(tuple(my_new_dict))
print(set(my_new_dict))
