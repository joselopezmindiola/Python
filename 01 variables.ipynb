# %%
# concatenacion de variables en un print
print(my_string_variable, my_int_to-str_variable, my_bool_variable)
print("este es el valor de:", my_variable)

#Algunas funciones del sistema
print(len(my_string_variable)) # len sirve para contar los caracteres de la variable,
#variables en una sola linea.¡ cuidado con abusar de esta sintaxis!
name,suname, alias, age="jose","lopez mindiola",'alumno', 15
print(" mellamo:", name, surname,". Mi edad es :",
      age,".y mi alias es :", alias)

#Inputs
name = input('¿cual estu nombre? ')
age = input('¿Cuantos años tienes?')
print(name)
print(age)


# Cambiamos su tipo
name= 35
age= "carlos"
print(name)
print(age)

#¿Forzamos el tipo?
address: str = "Mi direccion"
address = true
address = 5
address = 1.2
print(type(address))
